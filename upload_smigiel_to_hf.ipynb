# %%
import pandas as pd

def load_dataframe(path: str):
    return pd.DataFrame(data={'text': pd.read_csv(f"{path}/start.txt", sep='\n', header=None)})

dataset_dict = {
  'train': load_dataframe('data/postprocessed/train'),
}
dataset_dict
